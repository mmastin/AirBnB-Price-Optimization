# %%
import pandas as pd

listings = pd.read_csv('/Users/mattmastin/Desktop/airbnb/listings.csv')
listings_summary = pd.read_csv('/Users/mattmastin/Desktop/airbnb/listings_summary.csv')
hoods = pd.read_csv('/Users/mattmastin/Desktop/airbnb/neighbourhoods.csv')
reviews_summary = pd.read_csv('/Users/mattmastin/Desktop/airbnb/reviews_summary.csv')

# %%
print(listings.shape)
listings.head()
# Out:
# (22552, 16)
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood   latitude  longitude  \
# 0                   Mitte           Brunnenstr. Süd  52.534537  13.402557
# 1                  Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 2                  Pankow   Prenzlauer Berg Südwest  52.534996  13.417579
# 3  Tempelhof - Schöneberg           Schöneberg-Nord  52.498855  13.349065
# 4                  Pankow            Helmholtzplatz  52.543157  13.415091
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     60               4                118  2018-10-28
# 1     Private room     17               2                  6  2018-10-01
# 2  Entire home/apt     90              62                143  2017-03-20
# 3     Private room     26               5                 25  2018-08-16
# 4     Private room     42               2                197  2018-11-04
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               3.76                               4               141
# 1               1.42                               1                 0
# 2               1.25                               1               220
# 3               0.39                               1               297
# 4               1.75                               1                26

# %%
listings.describe(exclude='number')
# Out:
#                   name host_name       neighbourhood_group  \
# count            22493     22526                     22552
# unique           21873      5997                        12
# top     Berlin Wohnung      Anna  Friedrichshain-Kreuzberg
# freq                14       216                      5497
#
#                neighbourhood     room_type last_review
# count                  22552         22552       18644
# unique                   136             3        1312
# top     Tempelhofer Vorstadt  Private room  2018-11-04
# freq                    1325         11534         618

# %%
pd.set_option('display.max_columns', 500)

print(listings_summary.shape)
listings_summary.head()
# Out:
# (22552, 96)
#      id                        listing_url       scrape_id last_scraped  \
# 0  2015  https://www.airbnb.com/rooms/2015  20181107122246   2018-11-07
# 1  2695  https://www.airbnb.com/rooms/2695  20181107122246   2018-11-07
# 2  3176  https://www.airbnb.com/rooms/3176  20181107122246   2018-11-07
# 3  3309  https://www.airbnb.com/rooms/3309  20181107122246   2018-11-07
# 4  7071  https://www.airbnb.com/rooms/7071  20181107122246   2018-11-07
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
# 1                Prenzlauer Berg close to Mauerpark
# 2                   Fabulous Flat in great Location
# 3                 BerlinSpot Schöneberg near KaDeWe
# 4                  BrightRoom with sunny greenview!
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1                                                NaN
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                                space  \
# 0  A+++ location! This „Einliegerwohnung“ is an e...
# 1  In the summertime we are spending most of our ...
# 2  1st floor (68m2) apartment on Kollwitzplatz/ P...
# 3  Your room is really big and has 26 sqm, is ver...
# 4  The BrightRoom is an approx. 20 sqm (215ft²), ...
#
#                                          description experiences_offered  \
# 0  Great location!  30 of 75 sq meters. This wood...                none
# 1  In the summertime we are spending most of our ...                none
# 2  This beautiful first floor apartment  is situa...                none
# 3  First of all: I prefer short-notice bookings. ...                none
# 4  Cozy and large room in the beautiful district ...                none
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1                                                NaN
# 2  The neighbourhood is famous for its variety of...
# 3  My flat is in the middle of West-Berlin, direc...
# 4  Great neighborhood with plenty of Cafés, Baker...
#
#                                                notes  \
# 0  This is my home, not a hotel. I rent out occas...
# 1                                                NaN
# 2  We welcome FAMILIES and cater especially for y...
# 3  The flat is a strictly non-smoking facility! A...
# 4  I hope you enjoy your stay to the fullest! Ple...
#
#                                              transit  \
# 0  Close to U-Bahn U8 and U2 (metro), Trams M12, ...
# 1  Within walking distance you'll find the S-Bahn...
# 2  We are 5 min walk  away from the tram M2, whic...
# 3  The public transportation is excellent: Severa...
# 4  Best access to other parts of the city via pub...
#
#                                               access  \
# 0  Simple kitchen/cooking, refrigerator, microwav...
# 1  Außer deinem Zimmer kannst du noch die Küche u...
# 2  The apartment will be entirely yours. We are c...
# 3  I do have a strictly non-smoker-flat.  Keep th...
# 4  The guests have access to the bathroom, a smal...
#
#                                          interaction  \
# 0                                   Always available
# 1                                                NaN
# 2  Feel free to ask any questions prior to bookin...
# 3  I'm working as a freelancing photographer. My ...
# 4  I am glad if I can give you advice or help as ...
#
#                                          house_rules  thumbnail_url  \
# 0  No parties No events No pets No smoking, not e...            NaN
# 1                                                NaN            NaN
# 2  It’s a non smoking flat, which likes to be tre...            NaN
# 3  House-Rules and Information ..............(deu...            NaN
# 4  Please take good care of everything during you...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/260fd609-7...
# 1         NaN  https://a0.muscache.com/im/pictures/97d4f6e8-1...
# 2         NaN  https://a0.muscache.com/im/pictures/243355/84a...
# 3         NaN  https://a0.muscache.com/im/pictures/29054294/b...
# 4         NaN  https://a0.muscache.com/im/pictures/21278/32a1...
#
#    xl_picture_url  host_id                                 host_url host_name  \
# 0             NaN     2217   https://www.airbnb.com/users/show/2217       Ian
# 1             NaN     2986   https://www.airbnb.com/users/show/2986   Michael
# 2             NaN     3718   https://www.airbnb.com/users/show/3718    Britta
# 3             NaN     4108   https://www.airbnb.com/users/show/4108      Jana
# 4             NaN    17391  https://www.airbnb.com/users/show/17391    Bright
#
#    host_since                         host_location  \
# 0  2008-08-18  Key Biscayne, Florida, United States
# 1  2008-09-16               Berlin, Berlin, Germany
# 2  2008-10-19  Coledale, New South Wales, Australia
# 3  2008-11-07               Berlin, Berlin, Germany
# 4  2009-05-16               Berlin, Berlin, Germany
#
#                                           host_about host_response_time  \
# 0                        Believe in sharing economy.     within an hour
# 1  Living with my wife in Berlin.  Like travellin...                NaN
# 2  We love to travel ourselves a lot and prefer t...       within a day
# 3  ENJOY EVERY DAY AS IF IT'S YOUR LAST!!! \r\n\r...                NaN
# 4  I'm a creative person, adventurer, and travele...     within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                96%                   NaN                 t
# 1                NaN                   NaN                 f
# 2               100%                   NaN                 f
# 3                NaN                   NaN                 f
# 4               100%                   NaN                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/21428a22-4...
# 1  https://a0.muscache.com/im/pictures/50434955-1...
# 2  https://a0.muscache.com/im/users/3718/profile_...
# 3  https://a0.muscache.com/im/pictures/user/b5938...
# 4  https://a0.muscache.com/im/pictures/user/48c3d...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/21428a22-4...              Mitte
# 1  https://a0.muscache.com/im/pictures/50434955-1...    Prenzlauer Berg
# 2  https://a0.muscache.com/im/users/3718/profile_...    Prenzlauer Berg
# 3  https://a0.muscache.com/im/pictures/user/b5938...         Schöneberg
# 4  https://a0.muscache.com/im/pictures/user/48c3d...    Prenzlauer Berg
#
#    host_listings_count  host_total_listings_count  \
# 0                  4.0                        4.0
# 1                  1.0                        1.0
# 2                  1.0                        1.0
# 3                  1.0                        1.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 2  ['email', 'phone', 'facebook', 'reviews', 'man...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
#
#   host_identity_verified                   street    neighbourhood  \
# 0                      t  Berlin, Berlin, Germany            Mitte
# 1                      t  Berlin, Berlin, Germany              NaN
# 2                      t  Berlin, Berlin, Germany  Prenzlauer Berg
# 3                      t  Berlin, Berlin, Germany       Schöneberg
# 4                      t  Berlin, Berlin, Germany  Prenzlauer Berg
#
#      neighbourhood_cleansed neighbourhood_group_cleansed    city   state  \
# 0           Brunnenstr. Süd                        Mitte  Berlin  Berlin
# 1  Prenzlauer Berg Nordwest                       Pankow  Berlin  Berlin
# 2   Prenzlauer Berg Südwest                       Pankow  Berlin  Berlin
# 3           Schöneberg-Nord       Tempelhof - Schöneberg  Berlin  Berlin
# 4            Helmholtzplatz                       Pankow  Berlin  Berlin
#
#   zipcode  market   smart_location country_code  country   latitude  \
# 0   10119  Berlin  Berlin, Germany           DE  Germany  52.534537
# 1   10437  Berlin  Berlin, Germany           DE  Germany  52.548513
# 2   10405  Berlin  Berlin, Germany           DE  Germany  52.534996
# 3   10777  Berlin  Berlin, Germany           DE  Germany  52.498855
# 4   10437  Berlin  Berlin, Germany           DE  Germany  52.543157
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0  13.402557                 f    Guesthouse  Entire home/apt             3
# 1  13.404553                 t     Apartment     Private room             2
# 2  13.417579                 t     Apartment  Entire home/apt             4
# 3  13.349065                 t     Apartment     Private room             2
# 4  13.415091                 t     Apartment     Private room             2
#
#    bathrooms  bedrooms  beds       bed_type  \
# 0        1.0       1.0   2.0       Real Bed
# 1        1.0       1.0   1.0       Real Bed
# 2        1.0       1.0   2.0       Real Bed
# 3        1.0       1.0   1.0  Pull-out Sofa
# 4        1.0       1.0   2.0       Real Bed
#
#                                            amenities  square_feet   price  \
# 0  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...          NaN  $60.00
# 1  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...          NaN  $17.00
# 2  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...        720.0  $90.00
# 3  {Internet,Wifi,"Pets allowed","Pets live on th...          0.0  $26.00
# 4  {Wifi,Heating,"Family/kid friendly",Essentials...          NaN  $42.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN          $200.00       $30.00                1
# 1          NaN           NaN            $0.00        $0.00                1
# 2      $520.00     $1,900.00          $200.00       $50.00                2
# 3      $175.00       $599.00          $250.00       $30.00                1
# 4          NaN           NaN            $0.00        $0.00                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0       $28.00               4            1125     3 months ago
# 1        $0.00               2              40      7 weeks ago
# 2       $20.00              62            1125       a week ago
# 3       $18.00               5             360      4 weeks ago
# 4       $24.00               2              10       3 days ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0               21               51
# 1                t                0                0                0
# 2                t                0                0                0
# 3                t                0                0               22
# 4                t               15               26               26
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0               141            2018-11-07                118   2016-04-11
# 1                 0            2018-11-07                  6   2018-07-04
# 2               220            2018-11-07                143   2009-06-20
# 3               297            2018-11-07                 25   2013-08-12
# 4                26            2018-11-07                197   2009-08-18
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2018-10-28                  93.0                    10.0
# 1  2018-10-01                 100.0                    10.0
# 2  2017-03-20                  92.0                     9.0
# 3  2018-08-16                  88.0                     9.0
# 4  2018-11-04                  96.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        9.0                   10.0
# 1                       10.0                   10.0
# 2                        9.0                    9.0
# 3                        9.0                    9.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                         10.0                    10.0                 10.0
# 2                          9.0                    10.0                  9.0
# 3                         10.0                     9.0                  9.0
# 4                         10.0                    10.0                  9.0
#
#   requires_license license  jurisdiction_names instant_bookable  \
# 0                t     NaN                 NaN                f
# 1                t     NaN                 NaN                f
# 2                t     NaN                 NaN                t
# 3                t     NaN                 NaN                f
# 4                t     NaN                 NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               4               3.76
# 1                               1               1.42
# 2                               1               1.25
# 3                               1               0.39
# 4                               1               1.75

# %%
listings_summary.describe(exclude='number')
# Out:
#                                  listing_url last_scraped            name  \
# count                                  22552        22552           22493
# unique                                 22552            2           21873
# top     https://www.airbnb.com/rooms/6082385   2018-11-07  Berlin Wohnung
# freq                                       1        22549              14
#
#                                                   summary  \
# count                                               21589
# unique                                              21041
# top     with en-suite bathroom, TV, WIFI, bed linen, a...
# freq                                                   14
#
#                                                     space  \
# count                                               14020
# unique                                              13598
# top     The Singer 109 Hostel is located in the heart ...
# freq                                                   41
#
#                                               description experiences_offered  \
# count                                               22349               22552
# unique                                              21997                   1
# top     with en-suite bathroom, TV, WIFI, bed linen, a...                none
# freq                                                   12               22552
#
#                                     neighborhood_overview  \
# count                                               11540
# unique                                              10781
# top     Welcome Traveler. The Singer Hostel and  Apart...
# freq                                                   43
#
#                                                     notes  \
# count                                                7215
# unique                                               6687
# top     Since 01.01.2014 the city of Berlin had to ado...
# freq                                                   37
#
#                                                   transit  \
# count                                               13036
# unique                                              12308
# top     U-Bahn / Underground /Subway / Metro: U5 (Stra...
# freq                                                   26
#
#                                                    access  \
# count                                               10837
# unique                                               9946
# top     We can offer our guests - Pool table/Snooker -...
# freq                                                   42
#
#                                               interaction  \
# count                                               10406
# unique                                               9584
# top     There is always at least 1 member of staff on ...
# freq                                                   43
#
#                                               house_rules  \
# count                                               11449
# unique                                              10350
# top     - Most importantly, please have a respectful a...
# freq                                                   30
#
#                                               picture_url  \
# count                                               22552
# unique                                              22465
# top     https://a0.muscache.com/im/pictures/cedbe275-5...
# freq                                                    3
#
#                                          host_url host_name  host_since  \
# count                                       22552     22526       22526
# unique                                      19180      5997        2914
# top     https://www.airbnb.com/users/show/1625771      Anna  2013-08-19
# freq                                           45       216          51
#
#                   host_location host_about host_response_time  \
# count                     22436      11189               9658
# unique                     1036       8879                  4
# top     Berlin, Berlin, Germany          .     within an hour
# freq                      17188         71               5081
#
#        host_response_rate host_is_superhost  \
# count                9657             22526
# unique                 64                 2
# top                  100%                 f
# freq                 7127             19515
#
#                                        host_thumbnail_url  \
# count                                               22526
# unique                                              19100
# top     https://a0.muscache.com/defaults/user_pic-50x5...
# freq                                                   56
#
#                                          host_picture_url host_neighbourhood  \
# count                                               22526              17458
# unique                                              19100                181
# top     https://a0.muscache.com/defaults/user_pic-225x...           Neukölln
# freq                                                   56               2556
#
#                    host_verifications host_has_profile_pic  \
# count                           22552                22526
# unique                            301                    2
# top     ['email', 'phone', 'reviews']                    t
# freq                             4103                22470
#
#        host_identity_verified                   street neighbourhood  \
# count                   22526                    22552         21421
# unique                      2                       86            91
# top                         f  Berlin, Berlin, Germany      Neukölln
# freq                    13824                    22317          3209
#
#        neighbourhood_cleansed neighbourhood_group_cleansed    city   state  \
# count                   22552                        22552   22547   22468
# unique                    136                           12      60      19
# top      Tempelhofer Vorstadt     Friedrichshain-Kreuzberg  Berlin  Berlin
# freq                     1325                         5497   22417   22417
#
#        zipcode  market   smart_location country_code  country  \
# count    21896   22489            22552        22552    22552
# unique     215       6               61            1        1
# top      10245  Berlin  Berlin, Germany           DE  Germany
# freq       855   22483            22419        22552    22552
#
#        is_location_exact property_type     room_type  bed_type amenities  \
# count              22552         22552         22552     22552     22552
# unique                 2            33             3         5     19985
# top                    t     Apartment  Private room  Real Bed        {}
# freq               16776         20225         11534     21766        75
#
#          price weekly_price monthly_price security_deposit cleaning_fee  \
# count    22552         3681          2659            13191        15406
# unique     295          387           426              142          112
# top     $30.00      $300.00     $1,200.00            $0.00        $0.00
# freq      1387          232           143             5319         1865
#
#        extra_people calendar_updated has_availability calendar_last_scraped  \
# count         22552            22552            22552                 22552
# unique           65               75                1                     2
# top           $0.00            today                t            2018-11-07
# freq          10863             2517            22552                 22549
#
#        first_review last_review requires_license     license instant_bookable  \
# count         18638       18644            22552        1638            22552
# unique         2228        1312                2        1387                2
# top      2017-05-28  2018-11-04                t  HRB155306B                f
# freq            116         618            22544          35            15518
#
#        is_business_travel_ready cancellation_policy  \
# count                     22552               22552
# unique                        1                   5
# top                           f            flexible
# freq                      22552                9102
#
#        require_guest_profile_picture require_guest_phone_verification
# count                          22552                            22552
# unique                             2                                2
# top                                f                                f
# freq                           22396                            22273

# %%
pd.set_option('display.max_rows', 500)
listings_summary.isnull().sum()
# Out:
# id                                      0
# listing_url                             0
# scrape_id                               0
# last_scraped                            0
# name                                   59
# summary                               963
# space                                8532
# description                           203
# experiences_offered                     0
# neighborhood_overview               11012
# notes                               15337
# transit                              9516
# access                              11715
# interaction                         12146
# house_rules                         11103
# thumbnail_url                       22552
# medium_url                          22552
# picture_url                             0
# xl_picture_url                      22552
# host_id                                 0
# host_url                                0
# host_name                              26
# host_since                             26
# host_location                         116
# host_about                          11363
# host_response_time                  12894
# host_response_rate                  12895
# host_acceptance_rate                22552
# host_is_superhost                      26
# host_thumbnail_url                     26
# host_picture_url                       26
# host_neighbourhood                   5094
# host_listings_count                    26
# host_total_listings_count              26
# host_verifications                      0
# host_has_profile_pic                   26
# host_identity_verified                 26
# street                                  0
# neighbourhood                        1131
# neighbourhood_cleansed                  0
# neighbourhood_group_cleansed            0
# city                                    5
# state                                  84
# zipcode                               656
# market                                 63
# smart_location                          0
# country_code                            0
# country                                 0
# latitude                                0
# longitude                               0
# is_location_exact                       0
# property_type                           0
# room_type                               0
# accommodates                            0
# bathrooms                              32
# bedrooms                               18
# beds                                   40
# bed_type                                0
# amenities                               0
# square_feet                         22106
# price                                   0
# weekly_price                        18871
# monthly_price                       19893
# security_deposit                     9361
# cleaning_fee                         7146
# guests_included                         0
# extra_people                            0
# minimum_nights                          0
# maximum_nights                          0
# calendar_updated                        0
# has_availability                        0
# availability_30                         0
# availability_60                         0
# availability_90                         0
# availability_365                        0
# calendar_last_scraped                   0
# number_of_reviews                       0
# first_review                         3914
# last_review                          3908
# review_scores_rating                 4389
# review_scores_accuracy               4414
# review_scores_cleanliness            4411
# review_scores_checkin                4432
# review_scores_communication          4418
# review_scores_location               4431
# review_scores_value                  4435
# requires_license                        0
# license                             20914
# jurisdiction_names                  22552
# instant_bookable                        0
# is_business_travel_ready                0
# cancellation_policy                     0
# require_guest_profile_picture           0
# require_guest_phone_verification        0
# calculated_host_listings_count          0
# reviews_per_month                    3914
# dtype: int64

# %%
print(hoods.shape)
hoods.head()
# Out:
# (139, 2)
#     neighbourhood_group        neighbourhood
# 0  Charlottenburg-Wilm.            Barstraße
# 1  Charlottenburg-Wilm.  Charlottenburg Nord
# 2  Charlottenburg-Wilm.  Düsseldorfer Straße
# 3  Charlottenburg-Wilm.      Forst Grunewald
# 4  Charlottenburg-Wilm.            Grunewald

# %%
listings.isnull().sum()
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
listings_summary.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  2.255200e+04  2.255200e+04            0.0         0.0             0.0
# mean   1.571560e+07  2.018111e+13            NaN         NaN             NaN
# std    8.552069e+06  4.812607e+00            NaN         NaN             NaN
# min    2.015000e+03  2.018111e+13            NaN         NaN             NaN
# 25%    8.065954e+06  2.018111e+13            NaN         NaN             NaN
# 50%    1.686638e+07  2.018111e+13            NaN         NaN             NaN
# 75%    2.258393e+07  2.018111e+13            NaN         NaN             NaN
# max    2.986735e+07  2.018111e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  2.255200e+04                   0.0         22526.000000
# mean   5.403355e+07                   NaN             2.330685
# std    5.816290e+07                   NaN            19.947823
# min    2.217000e+03                   NaN             0.000000
# 25%    9.240002e+06                   NaN             1.000000
# 50%    3.126711e+07                   NaN             1.000000
# 75%    8.067518e+07                   NaN             2.000000
# max    2.245081e+08                   NaN          1676.000000
#
#        host_total_listings_count      latitude     longitude  accommodates  \
# count               22526.000000  22552.000000  22552.000000  22552.000000
# mean                    2.330685     52.509824     13.406107      2.637460
# std                    19.947823      0.030825      0.057964      1.510548
# min                     0.000000     52.345803     13.103557      1.000000
# 25%                     1.000000     52.489065     13.375411      2.000000
# 50%                     1.000000     52.509079     13.416779      2.000000
# 75%                     2.000000     52.532669     13.439259      3.000000
# max                  1676.000000     52.651670     13.757642     16.000000
#
#           bathrooms      bedrooms          beds  square_feet  guests_included  \
# count  22520.000000  22534.000000  22512.000000   446.000000     22552.000000
# mean       1.092695      1.161134      1.620558   465.401345         1.332121
# std        0.329894      0.646156      1.174840   503.491935         0.835034
# min        0.000000      0.000000      0.000000     0.000000         1.000000
# 25%        1.000000      1.000000      1.000000     0.000000         1.000000
# 50%        1.000000      1.000000      1.000000   403.500000         1.000000
# 75%        1.000000      1.000000      2.000000   707.500000         1.000000
# max        8.500000     12.000000     22.000000  4639.000000        16.000000
#
#        minimum_nights  maximum_nights  availability_30  availability_60  \
# count    22552.000000    2.255200e+04     22552.000000     22552.000000
# mean         7.157059    1.030505e+05         4.944173        11.146639
# std         40.665073    9.640519e+06         8.677395        17.522371
# min          1.000000    1.000000e+00         0.000000         0.000000
# 25%          2.000000    2.000000e+01         0.000000         0.000000
# 50%          2.000000    1.124000e+03         0.000000         0.000000
# 75%          4.000000    1.125000e+03         6.000000        18.000000
# max       5000.000000    1.000000e+09        30.000000        60.000000
#
#        availability_90  availability_365  number_of_reviews  \
# count     22552.000000      22552.000000       22552.000000
# mean         20.016096         79.852829          17.840679
# std          28.349136        119.368162          36.769624
# min           0.000000          0.000000           0.000000
# 25%           0.000000          0.000000           1.000000
# 50%           0.000000          4.000000           5.000000
# 75%          36.000000        129.000000          16.000000
# max          90.000000        365.000000         498.000000
#
#        review_scores_rating  review_scores_accuracy  \
# count          18163.000000            18138.000000
# mean              94.413863                9.663965
# std                7.639644                0.740039
# min               20.000000                2.000000
# 25%               92.000000               10.000000
# 50%               97.000000               10.000000
# 75%              100.000000               10.000000
# max              100.000000               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               18141.000000           18120.000000
# mean                    9.324955               9.713521
# std                     1.031996               0.704620
# min                     2.000000               2.000000
# 25%                     9.000000              10.000000
# 50%                    10.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                 18134.000000            18121.000000
# mean                      9.730672                9.505491
# std                       0.686614                0.762161
# min                       2.000000                2.000000
# 25%                      10.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  jurisdiction_names  \
# count         18117.000000                 0.0
# mean              9.411106                 NaN
# std               0.841492                 NaN
# min               2.000000                 NaN
# 25%               9.000000                 NaN
# 50%              10.000000                 NaN
# 75%              10.000000                 NaN
# max              10.000000                 NaN
#
#        calculated_host_listings_count  reviews_per_month
# count                    22552.000000       18638.000000
# mean                         1.918233           1.135525
# std                          3.667257           1.507082
# min                          1.000000           0.010000
# 25%                          1.000000           0.180000
# 50%                          1.000000           0.540000
# 75%                          1.000000           1.500000
# max                         45.000000          36.670000

# %%
listings_summary = listings_summary.drop(columns=['id', 'host_name', 'latitude', 'longitude', 'room type', 'price'])

# %%
df = pd.concat([listings, listings_summary], axis=1)

# %%
print(df.shape)
df.head()
# Out:
# (22552, 112)
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood   latitude  longitude  \
# 0                   Mitte           Brunnenstr. Süd  52.534537  13.402557
# 1                  Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 2                  Pankow   Prenzlauer Berg Südwest  52.534996  13.417579
# 3  Tempelhof - Schöneberg           Schöneberg-Nord  52.498855  13.349065
# 4                  Pankow            Helmholtzplatz  52.543157  13.415091
#
#          room_type price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    60               4                118  2018-10-28
# 1     Private room    17               2                  6  2018-10-01
# 2  Entire home/apt    90              62                143  2017-03-20
# 3     Private room    26               5                 25  2018-08-16
# 4     Private room    42               2                197  2018-11-04
#
#    reviews_per_month  calculated_host_listings_count  availability_365    id  \
# 0               3.76                               4               141  2015
# 1               1.42                               1                 0  2695
# 2               1.25                               1               220  3176
# 3               0.39                               1               297  3309
# 4               1.75                               1                26  7071
#
#                          listing_url       scrape_id last_scraped  \
# 0  https://www.airbnb.com/rooms/2015  20181107122246   2018-11-07
# 1  https://www.airbnb.com/rooms/2695  20181107122246   2018-11-07
# 2  https://www.airbnb.com/rooms/3176  20181107122246   2018-11-07
# 3  https://www.airbnb.com/rooms/3309  20181107122246   2018-11-07
# 4  https://www.airbnb.com/rooms/7071  20181107122246   2018-11-07
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
# 1                Prenzlauer Berg close to Mauerpark
# 2                   Fabulous Flat in great Location
# 3                 BerlinSpot Schöneberg near KaDeWe
# 4                  BrightRoom with sunny greenview!
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1                                                NaN
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                                space  \
# 0  A+++ location! This „Einliegerwohnung“ is an e...
# 1  In the summertime we are spending most of our ...
# 2  1st floor (68m2) apartment on Kollwitzplatz/ P...
# 3  Your room is really big and has 26 sqm, is ver...
# 4  The BrightRoom is an approx. 20 sqm (215ft²), ...
#
#                                          description experiences_offered  \
# 0  Great location!  30 of 75 sq meters. This wood...                none
# 1  In the summertime we are spending most of our ...                none
# 2  This beautiful first floor apartment  is situa...                none
# 3  First of all: I prefer short-notice bookings. ...                none
# 4  Cozy and large room in the beautiful district ...                none
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1                                                NaN
# 2  The neighbourhood is famous for its variety of...
# 3  My flat is in the middle of West-Berlin, direc...
# 4  Great neighborhood with plenty of Cafés, Baker...
#
#                                                notes  \
# 0  This is my home, not a hotel. I rent out occas...
# 1                                                NaN
# 2  We welcome FAMILIES and cater especially for y...
# 3  The flat is a strictly non-smoking facility! A...
# 4  I hope you enjoy your stay to the fullest! Ple...
#
#                                              transit  \
# 0  Close to U-Bahn U8 and U2 (metro), Trams M12, ...
# 1  Within walking distance you'll find the S-Bahn...
# 2  We are 5 min walk  away from the tram M2, whic...
# 3  The public transportation is excellent: Severa...
# 4  Best access to other parts of the city via pub...
#
#                                               access  \
# 0  Simple kitchen/cooking, refrigerator, microwav...
# 1  Außer deinem Zimmer kannst du noch die Küche u...
# 2  The apartment will be entirely yours. We are c...
# 3  I do have a strictly non-smoker-flat.  Keep th...
# 4  The guests have access to the bathroom, a smal...
#
#                                          interaction  \
# 0                                   Always available
# 1                                                NaN
# 2  Feel free to ask any questions prior to bookin...
# 3  I'm working as a freelancing photographer. My ...
# 4  I am glad if I can give you advice or help as ...
#
#                                          house_rules  thumbnail_url  \
# 0  No parties No events No pets No smoking, not e...            NaN
# 1                                                NaN            NaN
# 2  It’s a non smoking flat, which likes to be tre...            NaN
# 3  House-Rules and Information ..............(deu...            NaN
# 4  Please take good care of everything during you...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/260fd609-7...
# 1         NaN  https://a0.muscache.com/im/pictures/97d4f6e8-1...
# 2         NaN  https://a0.muscache.com/im/pictures/243355/84a...
# 3         NaN  https://a0.muscache.com/im/pictures/29054294/b...
# 4         NaN  https://a0.muscache.com/im/pictures/21278/32a1...
#
#    xl_picture_url  host_id                                 host_url host_name  \
# 0             NaN     2217   https://www.airbnb.com/users/show/2217       Ian
# 1             NaN     2986   https://www.airbnb.com/users/show/2986   Michael
# 2             NaN     3718   https://www.airbnb.com/users/show/3718    Britta
# 3             NaN     4108   https://www.airbnb.com/users/show/4108      Jana
# 4             NaN    17391  https://www.airbnb.com/users/show/17391    Bright
#
#    host_since                         host_location  \
# 0  2008-08-18  Key Biscayne, Florida, United States
# 1  2008-09-16               Berlin, Berlin, Germany
# 2  2008-10-19  Coledale, New South Wales, Australia
# 3  2008-11-07               Berlin, Berlin, Germany
# 4  2009-05-16               Berlin, Berlin, Germany
#
#                                           host_about host_response_time  \
# 0                        Believe in sharing economy.     within an hour
# 1  Living with my wife in Berlin.  Like travellin...                NaN
# 2  We love to travel ourselves a lot and prefer t...       within a day
# 3  ENJOY EVERY DAY AS IF IT'S YOUR LAST!!! \r\n\r...                NaN
# 4  I'm a creative person, adventurer, and travele...     within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0                96%                   NaN                 t
# 1                NaN                   NaN                 f
# 2               100%                   NaN                 f
# 3                NaN                   NaN                 f
# 4               100%                   NaN                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/21428a22-4...
# 1  https://a0.muscache.com/im/pictures/50434955-1...
# 2  https://a0.muscache.com/im/users/3718/profile_...
# 3  https://a0.muscache.com/im/pictures/user/b5938...
# 4  https://a0.muscache.com/im/pictures/user/48c3d...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/21428a22-4...              Mitte
# 1  https://a0.muscache.com/im/pictures/50434955-1...    Prenzlauer Berg
# 2  https://a0.muscache.com/im/users/3718/profile_...    Prenzlauer Berg
# 3  https://a0.muscache.com/im/pictures/user/b5938...         Schöneberg
# 4  https://a0.muscache.com/im/pictures/user/48c3d...    Prenzlauer Berg
#
#    host_listings_count  host_total_listings_count  \
# 0                  4.0                        4.0
# 1                  1.0                        1.0
# 2                  1.0                        1.0
# 3                  1.0                        1.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 2  ['email', 'phone', 'facebook', 'reviews', 'man...                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
#
#   host_identity_verified                   street    neighbourhood  \
# 0                      t  Berlin, Berlin, Germany            Mitte
# 1                      t  Berlin, Berlin, Germany              NaN
# 2                      t  Berlin, Berlin, Germany  Prenzlauer Berg
# 3                      t  Berlin, Berlin, Germany       Schöneberg
# 4                      t  Berlin, Berlin, Germany  Prenzlauer Berg
#
#      neighbourhood_cleansed neighbourhood_group_cleansed    city   state  \
# 0           Brunnenstr. Süd                        Mitte  Berlin  Berlin
# 1  Prenzlauer Berg Nordwest                       Pankow  Berlin  Berlin
# 2   Prenzlauer Berg Südwest                       Pankow  Berlin  Berlin
# 3           Schöneberg-Nord       Tempelhof - Schöneberg  Berlin  Berlin
# 4            Helmholtzplatz                       Pankow  Berlin  Berlin
#
#   zipcode  market   smart_location country_code  country   latitude  \
# 0   10119  Berlin  Berlin, Germany           DE  Germany  52.534537
# 1   10437  Berlin  Berlin, Germany           DE  Germany  52.548513
# 2   10405  Berlin  Berlin, Germany           DE  Germany  52.534996
# 3   10777  Berlin  Berlin, Germany           DE  Germany  52.498855
# 4   10437  Berlin  Berlin, Germany           DE  Germany  52.543157
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0  13.402557                 f    Guesthouse  Entire home/apt             3
# 1  13.404553                 t     Apartment     Private room             2
# 2  13.417579                 t     Apartment  Entire home/apt             4
# 3  13.349065                 t     Apartment     Private room             2
# 4  13.415091                 t     Apartment     Private room             2
#
#    bathrooms  bedrooms  beds       bed_type  \
# 0        1.0       1.0   2.0       Real Bed
# 1        1.0       1.0   1.0       Real Bed
# 2        1.0       1.0   2.0       Real Bed
# 3        1.0       1.0   1.0  Pull-out Sofa
# 4        1.0       1.0   2.0       Real Bed
#
#                                            amenities  square_feet   price  \
# 0  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...          NaN  $60.00
# 1  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...          NaN  $17.00
# 2  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...        720.0  $90.00
# 3  {Internet,Wifi,"Pets allowed","Pets live on th...          0.0  $26.00
# 4  {Wifi,Heating,"Family/kid friendly",Essentials...          NaN  $42.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN          $200.00       $30.00                1
# 1          NaN           NaN            $0.00        $0.00                1
# 2      $520.00     $1,900.00          $200.00       $50.00                2
# 3      $175.00       $599.00          $250.00       $30.00                1
# 4          NaN           NaN            $0.00        $0.00                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0       $28.00               4            1125     3 months ago
# 1        $0.00               2              40      7 weeks ago
# 2       $20.00              62            1125       a week ago
# 3       $18.00               5             360      4 weeks ago
# 4       $24.00               2              10       3 days ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0               21               51
# 1                t                0                0                0
# 2                t                0                0                0
# 3                t                0                0               22
# 4                t               15               26               26
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0               141            2018-11-07                118   2016-04-11
# 1                 0            2018-11-07                  6   2018-07-04
# 2               220            2018-11-07                143   2009-06-20
# 3               297            2018-11-07                 25   2013-08-12
# 4                26            2018-11-07                197   2009-08-18
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2018-10-28                  93.0                    10.0
# 1  2018-10-01                 100.0                    10.0
# 2  2017-03-20                  92.0                     9.0
# 3  2018-08-16                  88.0                     9.0
# 4  2018-11-04                  96.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        9.0                   10.0
# 1                       10.0                   10.0
# 2                        9.0                    9.0
# 3                        9.0                    9.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                         10.0                    10.0                 10.0
# 2                          9.0                    10.0                  9.0
# 3                         10.0                     9.0                  9.0
# 4                         10.0                    10.0                  9.0
#
#   requires_license license  jurisdiction_names instant_bookable  \
# 0                t     NaN                 NaN                f
# 1                t     NaN                 NaN                f
# 2                t     NaN                 NaN                t
# 3                t     NaN                 NaN                f
# 4                t     NaN                 NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               4               3.76
# 1                               1               1.42
# 2                               1               1.25
# 3                               1               0.39
# 4                               1               1.75

# %%
listings_summary.isnull().sum()
# Out:
# id                                      0
# listing_url                             0
# scrape_id                               0
# last_scraped                            0
# name                                   59
# summary                               963
# space                                8532
# description                           203
# experiences_offered                     0
# neighborhood_overview               11012
# notes                               15337
# transit                              9516
# access                              11715
# interaction                         12146
# house_rules                         11103
# thumbnail_url                       22552
# medium_url                          22552
# picture_url                             0
# xl_picture_url                      22552
# host_id                                 0
# host_url                                0
# host_name                              26
# host_since                             26
# host_location                         116
# host_about                          11363
# host_response_time                  12894
# host_response_rate                  12895
# host_acceptance_rate                22552
# host_is_superhost                      26
# host_thumbnail_url                     26
# host_picture_url                       26
# host_neighbourhood                   5094
# host_listings_count                    26
# host_total_listings_count              26
# host_verifications                      0
# host_has_profile_pic                   26
# host_identity_verified                 26
# street                                  0
# neighbourhood                        1131
# neighbourhood_cleansed                  0
# neighbourhood_group_cleansed            0
# city                                    5
# state                                  84
# zipcode                               656
# market                                 63
# smart_location                          0
# country_code                            0
# country                                 0
# latitude                                0
# longitude                               0
# is_location_exact                       0
# property_type                           0
# room_type                               0
# accommodates                            0
# bathrooms                              32
# bedrooms                               18
# beds                                   40
# bed_type                                0
# amenities                               0
# square_feet                         22106
# price                                   0
# weekly_price                        18871
# monthly_price                       19893
# security_deposit                     9361
# cleaning_fee                         7146
# guests_included                         0
# extra_people                            0
# minimum_nights                          0
# maximum_nights                          0
# calendar_updated                        0
# has_availability                        0
# availability_30                         0
# availability_60                         0
# availability_90                         0
# availability_365                        0
# calendar_last_scraped                   0
# number_of_reviews                       0
# first_review                         3914
# last_review                          3908
# review_scores_rating                 4389
# review_scores_accuracy               4414
# review_scores_cleanliness            4411
# review_scores_checkin                4432
# review_scores_communication          4418
# review_scores_location               4431
# review_scores_value                  4435
# requires_license                        0
# license                             20914
# jurisdiction_names                  22552
# instant_bookable                        0
# is_business_travel_ready                0
# cancellation_policy                     0
# require_guest_profile_picture           0
# require_guest_phone_verification        0
# calculated_host_listings_count          0
# reviews_per_month                    3914
# dtype: int64

# %%
df = listings_summmary.drop(['space', 'notes', 'access', 'interaction', 'house_rules',
                            'thumbnail_url', 'medium_url', 'xl_picture_url', 'host_about',
                            'host_response_time', 'host_response_rate', 'host_acceptance_rate',
                            'host_neighbourhood', 'host_listings_count', 'host_total_listings_count',
                            'host_verifications', 'host_identity_verified', 'is_location_exact',
                            'first_review', 'last_review'], axis=1)

# %%
df.isnull().sum()
# Out:
# id                                      0
# listing_url                             0
# name                                   59
# summary                               963
# description                           203
# experiences_offered                     0
# neighborhood_overview               11012
# transit                              9516
# picture_url                             0
# host_name                              26
# host_since                             26
# host_location                         116
# host_is_superhost                      26
# street                                  0
# neighbourhood                        1131
# neighbourhood_cleansed                  0
# neighbourhood_group_cleansed            0
# city                                    5
# state                                  84
# zipcode                               656
# market                                 63
# smart_location                          0
# latitude                                0
# longitude                               0
# property_type                           0
# room_type                               0
# accommodates                            0
# bathrooms                              32
# bedrooms                               18
# beds                                   40
# bed_type                                0
# amenities                               0
# price                                   0
# security_deposit                     9361
# cleaning_fee                         7146
# guests_included                         0
# extra_people                            0
# minimum_nights                          0
# maximum_nights                          0
# calendar_updated                        0
# has_availability                        0
# availability_30                         0
# availability_60                         0
# availability_90                         0
# availability_365                        0
# number_of_reviews                       0
# review_scores_rating                 4389
# review_scores_accuracy               4414
# review_scores_cleanliness            4411
# review_scores_checkin                4432
# review_scores_communication          4418
# review_scores_location               4431
# review_scores_value                  4435
# instant_bookable                        0
# is_business_travel_ready                0
# cancellation_policy                     0
# require_guest_phone_verification        0
# calculated_host_listings_count          0
# reviews_per_month                    3914
# dtype: int64

# %%
df.shape
# Out:
# (22552, 59)

# %%
df.head()
# Out:
#      id                        listing_url  \
# 0  2015  https://www.airbnb.com/rooms/2015
# 1  2695  https://www.airbnb.com/rooms/2695
# 2  3176  https://www.airbnb.com/rooms/3176
# 3  3309  https://www.airbnb.com/rooms/3309
# 4  7071  https://www.airbnb.com/rooms/7071
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
# 1                Prenzlauer Berg close to Mauerpark
# 2                   Fabulous Flat in great Location
# 3                 BerlinSpot Schöneberg near KaDeWe
# 4                  BrightRoom with sunny greenview!
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1                                                NaN
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                          description experiences_offered  \
# 0  Great location!  30 of 75 sq meters. This wood...                none
# 1  In the summertime we are spending most of our ...                none
# 2  This beautiful first floor apartment  is situa...                none
# 3  First of all: I prefer short-notice bookings. ...                none
# 4  Cozy and large room in the beautiful district ...                none
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1                                                NaN
# 2  The neighbourhood is famous for its variety of...
# 3  My flat is in the middle of West-Berlin, direc...
# 4  Great neighborhood with plenty of Cafés, Baker...
#
#                                              transit  \
# 0  Close to U-Bahn U8 and U2 (metro), Trams M12, ...
# 1  Within walking distance you'll find the S-Bahn...
# 2  We are 5 min walk  away from the tram M2, whic...
# 3  The public transportation is excellent: Severa...
# 4  Best access to other parts of the city via pub...
#
#                                          picture_url host_name  host_since  \
# 0  https://a0.muscache.com/im/pictures/260fd609-7...       Ian  2008-08-18
# 1  https://a0.muscache.com/im/pictures/97d4f6e8-1...   Michael  2008-09-16
# 2  https://a0.muscache.com/im/pictures/243355/84a...    Britta  2008-10-19
# 3  https://a0.muscache.com/im/pictures/29054294/b...      Jana  2008-11-07
# 4  https://a0.muscache.com/im/pictures/21278/32a1...    Bright  2009-05-16
#
#                           host_location host_is_superhost  \
# 0  Key Biscayne, Florida, United States                 t
# 1               Berlin, Berlin, Germany                 f
# 2  Coledale, New South Wales, Australia                 f
# 3               Berlin, Berlin, Germany                 f
# 4               Berlin, Berlin, Germany                 t
#
#                     street    neighbourhood    neighbourhood_cleansed  \
# 0  Berlin, Berlin, Germany            Mitte           Brunnenstr. Süd
# 1  Berlin, Berlin, Germany              NaN  Prenzlauer Berg Nordwest
# 2  Berlin, Berlin, Germany  Prenzlauer Berg   Prenzlauer Berg Südwest
# 3  Berlin, Berlin, Germany       Schöneberg           Schöneberg-Nord
# 4  Berlin, Berlin, Germany  Prenzlauer Berg            Helmholtzplatz
#
#   neighbourhood_group_cleansed    city   state zipcode  market  \
# 0                        Mitte  Berlin  Berlin   10119  Berlin
# 1                       Pankow  Berlin  Berlin   10437  Berlin
# 2                       Pankow  Berlin  Berlin   10405  Berlin
# 3       Tempelhof - Schöneberg  Berlin  Berlin   10777  Berlin
# 4                       Pankow  Berlin  Berlin   10437  Berlin
#
#     smart_location   latitude  longitude property_type        room_type  \
# 0  Berlin, Germany  52.534537  13.402557    Guesthouse  Entire home/apt
# 1  Berlin, Germany  52.548513  13.404553     Apartment     Private room
# 2  Berlin, Germany  52.534996  13.417579     Apartment  Entire home/apt
# 3  Berlin, Germany  52.498855  13.349065     Apartment     Private room
# 4  Berlin, Germany  52.543157  13.415091     Apartment     Private room
#
#    accommodates  bathrooms  bedrooms  beds       bed_type  \
# 0             3        1.0       1.0   2.0       Real Bed
# 1             2        1.0       1.0   1.0       Real Bed
# 2             4        1.0       1.0   2.0       Real Bed
# 3             2        1.0       1.0   1.0  Pull-out Sofa
# 4             2        1.0       1.0   2.0       Real Bed
#
#                                            amenities   price security_deposit  \
# 0  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...  $60.00          $200.00
# 1  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...  $17.00            $0.00
# 2  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...  $90.00          $200.00
# 3  {Internet,Wifi,"Pets allowed","Pets live on th...  $26.00          $250.00
# 4  {Wifi,Heating,"Family/kid friendly",Essentials...  $42.00            $0.00
#
#   cleaning_fee  guests_included extra_people  minimum_nights  maximum_nights  \
# 0       $30.00                1       $28.00               4            1125
# 1        $0.00                1        $0.00               2              40
# 2       $50.00                2       $20.00              62            1125
# 3       $30.00                1       $18.00               5             360
# 4        $0.00                1       $24.00               2              10
#
#   calendar_updated has_availability  availability_30  availability_60  \
# 0     3 months ago                t                0               21
# 1      7 weeks ago                t                0                0
# 2       a week ago                t                0                0
# 3      4 weeks ago                t                0                0
# 4       3 days ago                t               15               26
#
#    availability_90  availability_365  number_of_reviews  review_scores_rating  \
# 0               51               141                118                  93.0
# 1                0                 0                  6                 100.0
# 2                0               220                143                  92.0
# 3               22               297                 25                  88.0
# 4               26                26                197                  96.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                        9.0                   10.0
# 1                    10.0                       10.0                   10.0
# 2                     9.0                        9.0                    9.0
# 3                     9.0                        9.0                    9.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                         10.0                    10.0                 10.0
# 2                          9.0                    10.0                  9.0
# 3                         10.0                     9.0                  9.0
# 4                         10.0                    10.0                  9.0
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f  strict_14_with_grace_period
# 1                f                        f                     flexible
# 2                t                        f  strict_14_with_grace_period
# 3                f                        f  strict_14_with_grace_period
# 4                f                        f                     moderate
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               4
# 1                                f                               1
# 2                                f                               1
# 3                                f                               1
# 4                                f                               1
#
#    reviews_per_month
# 0               3.76
# 1               1.42
# 2               1.25
# 3               0.39
# 4               1.75

# %%
df = df.drop(columns=['listing_url', 'experiences_offered', 'picture_url', 'host_name',
                     'host_location', 'host_is_superhost', 'neighbourhood_cleansed',
                     'city', 'market', 'instant_bookable', 'is_business_travel_ready',
                     'require_guest_phone_verification', 'smart_location', 
                      'calendar_updated', 'has_availability', 'availability_30',
                     'availability_60', 'availability_90', 'availability_365',
                     'calculated_host_listings_count', 'review_scores_cleanliness',
                     'review_scores_checkin', 'review_scores_communication'], axis=1)

# %%
print(df.shape)
df.head()
# Out:
# (22552, 36)
#      id                                              name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central
# 1  2695                Prenzlauer Berg close to Mauerpark
# 2  3176                   Fabulous Flat in great Location
# 3  3309                 BerlinSpot Schöneberg near KaDeWe
# 4  7071                  BrightRoom with sunny greenview!
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1                                                NaN
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                          description  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1  In the summertime we are spending most of our ...
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1                                                NaN
# 2  The neighbourhood is famous for its variety of...
# 3  My flat is in the middle of West-Berlin, direc...
# 4  Great neighborhood with plenty of Cafés, Baker...
#
#                                              transit  host_since  \
# 0  Close to U-Bahn U8 and U2 (metro), Trams M12, ...  2008-08-18
# 1  Within walking distance you'll find the S-Bahn...  2008-09-16
# 2  We are 5 min walk  away from the tram M2, whic...  2008-10-19
# 3  The public transportation is excellent: Severa...  2008-11-07
# 4  Best access to other parts of the city via pub...  2009-05-16
#
#                     street    neighbourhood neighbourhood_group_cleansed  \
# 0  Berlin, Berlin, Germany            Mitte                        Mitte
# 1  Berlin, Berlin, Germany              NaN                       Pankow
# 2  Berlin, Berlin, Germany  Prenzlauer Berg                       Pankow
# 3  Berlin, Berlin, Germany       Schöneberg       Tempelhof - Schöneberg
# 4  Berlin, Berlin, Germany  Prenzlauer Berg                       Pankow
#
#     state zipcode   latitude  longitude property_type        room_type  \
# 0  Berlin   10119  52.534537  13.402557    Guesthouse  Entire home/apt
# 1  Berlin   10437  52.548513  13.404553     Apartment     Private room
# 2  Berlin   10405  52.534996  13.417579     Apartment  Entire home/apt
# 3  Berlin   10777  52.498855  13.349065     Apartment     Private room
# 4  Berlin   10437  52.543157  13.415091     Apartment     Private room
#
#    accommodates  bathrooms  bedrooms  beds       bed_type  \
# 0             3        1.0       1.0   2.0       Real Bed
# 1             2        1.0       1.0   1.0       Real Bed
# 2             4        1.0       1.0   2.0       Real Bed
# 3             2        1.0       1.0   1.0  Pull-out Sofa
# 4             2        1.0       1.0   2.0       Real Bed
#
#                                            amenities   price security_deposit  \
# 0  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...  $60.00          $200.00
# 1  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...  $17.00            $0.00
# 2  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...  $90.00          $200.00
# 3  {Internet,Wifi,"Pets allowed","Pets live on th...  $26.00          $250.00
# 4  {Wifi,Heating,"Family/kid friendly",Essentials...  $42.00            $0.00
#
#   cleaning_fee  guests_included extra_people  minimum_nights  maximum_nights  \
# 0       $30.00                1       $28.00               4            1125
# 1        $0.00                1        $0.00               2              40
# 2       $50.00                2       $20.00              62            1125
# 3       $30.00                1       $18.00               5             360
# 4        $0.00                1       $24.00               2              10
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 0                118                  93.0                    10.0
# 1                  6                 100.0                    10.0
# 2                143                  92.0                     9.0
# 3                 25                  88.0                     9.0
# 4                197                  96.0                    10.0
#
#    review_scores_location  review_scores_value          cancellation_policy  \
# 0                    10.0                  9.0  strict_14_with_grace_period
# 1                    10.0                 10.0                     flexible
# 2                    10.0                  9.0  strict_14_with_grace_period
# 3                     9.0                  9.0  strict_14_with_grace_period
# 4                    10.0                  9.0                     moderate
#
#    reviews_per_month
# 0               3.76
# 1               1.42
# 2               1.25
# 3               0.39
# 4               1.75

# %%
df = df.drop(columns=['host_since', 'street'], axis=1)

# %%
df['price'] = df['price'].str.replace('$', '')
df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].astype(float)

# %%
df['security_deposit'] = df['security_deposit'].str.replace('$', '')
df['security_deposit'] = df['security_deposit'].str.replace(',', '')
df['security_deposit'] = df['security_deposit'].astype(float)

# %%
df['cleaning_fee'] = df['cleaning_fee'].str.replace('$', '')
df['cleaning_fee'] = df['cleaning_fee'].str.replace(',', '')
df['cleaning_fee'] = df['cleaning_fee'].astype(float)

# %%
df.head()
# Out:
#      id                                              name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central
# 1  2695                Prenzlauer Berg close to Mauerpark
# 2  3176                   Fabulous Flat in great Location
# 3  3309                 BerlinSpot Schöneberg near KaDeWe
# 4  7071                  BrightRoom with sunny greenview!
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1                                                NaN
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                          description  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1  In the summertime we are spending most of our ...
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1                                                NaN
# 2  The neighbourhood is famous for its variety of...
# 3  My flat is in the middle of West-Berlin, direc...
# 4  Great neighborhood with plenty of Cafés, Baker...
#
#                                              transit    neighbourhood  \
# 0  Close to U-Bahn U8 and U2 (metro), Trams M12, ...            Mitte
# 1  Within walking distance you'll find the S-Bahn...              NaN
# 2  We are 5 min walk  away from the tram M2, whic...  Prenzlauer Berg
# 3  The public transportation is excellent: Severa...       Schöneberg
# 4  Best access to other parts of the city via pub...  Prenzlauer Berg
#
#   neighbourhood_group_cleansed   state zipcode   latitude  longitude  \
# 0                        Mitte  Berlin   10119  52.534537  13.402557
# 1                       Pankow  Berlin   10437  52.548513  13.404553
# 2                       Pankow  Berlin   10405  52.534996  13.417579
# 3       Tempelhof - Schöneberg  Berlin   10777  52.498855  13.349065
# 4                       Pankow  Berlin   10437  52.543157  13.415091
#
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0    Guesthouse  Entire home/apt             3        1.0       1.0   2.0
# 1     Apartment     Private room             2        1.0       1.0   1.0
# 2     Apartment  Entire home/apt             4        1.0       1.0   2.0
# 3     Apartment     Private room             2        1.0       1.0   1.0
# 4     Apartment     Private room             2        1.0       1.0   2.0
#
#         bed_type                                          amenities  price  \
# 0       Real Bed  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...   60.0
# 1       Real Bed  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...   17.0
# 2       Real Bed  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...   90.0
# 3  Pull-out Sofa  {Internet,Wifi,"Pets allowed","Pets live on th...   26.0
# 4       Real Bed  {Wifi,Heating,"Family/kid friendly",Essentials...   42.0
#
#    security_deposit  cleaning_fee  guests_included extra_people  \
# 0             200.0          30.0                1       $28.00
# 1               0.0           0.0                1        $0.00
# 2             200.0          50.0                2       $20.00
# 3             250.0          30.0                1       $18.00
# 4               0.0           0.0                1       $24.00
#
#    minimum_nights  maximum_nights  number_of_reviews  review_scores_rating  \
# 0               4            1125                118                  93.0
# 1               2              40                  6                 100.0
# 2              62            1125                143                  92.0
# 3               5             360                 25                  88.0
# 4               2              10                197                  96.0
#
#    review_scores_accuracy  review_scores_location  review_scores_value  \
# 0                    10.0                    10.0                  9.0
# 1                    10.0                    10.0                 10.0
# 2                     9.0                    10.0                  9.0
# 3                     9.0                     9.0                  9.0
# 4                    10.0                    10.0                  9.0
#
#            cancellation_policy  reviews_per_month
# 0  strict_14_with_grace_period               3.76
# 1                     flexible               1.42
# 2  strict_14_with_grace_period               1.25
# 3  strict_14_with_grace_period               0.39
# 4                     moderate               1.75

# %%
df.shape
# Out:
# (22552, 34)

# %%
df['extra_people'] = df['extra_people'].str.replace('$', '')
df['extra_people'] = df['extra_people'].str.replace(',', '')
df['extra_people'] = df['extra_people'].astype(float)

# %%
df.dtypes
# Out:
# id                                int64
# name                             object
# summary                          object
# description                      object
# neighborhood_overview            object
# transit                          object
# neighbourhood                    object
# neighbourhood_group_cleansed     object
# state                            object
# zipcode                          object
# latitude                        float64
# longitude                       float64
# property_type                    object
# room_type                        object
# accommodates                      int64
# bathrooms                       float64
# bedrooms                        float64
# beds                            float64
# bed_type                         object
# amenities                        object
# price                           float64
# security_deposit                float64
# cleaning_fee                    float64
# guests_included                   int64
# extra_people                    float64
# minimum_nights                    int64
# maximum_nights                    int64
# number_of_reviews                 int64
# review_scores_rating            float64
# review_scores_accuracy          float64
# review_scores_location          float64
# review_scores_value             float64
# cancellation_policy              object
# reviews_per_month               float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                                  0
# name                               59
# summary                           963
# description                       203
# neighborhood_overview           11012
# transit                          9516
# neighbourhood                    1131
# neighbourhood_group_cleansed        0
# state                              84
# zipcode                           656
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# accommodates                        0
# bathrooms                          32
# bedrooms                           18
# beds                               40
# bed_type                            0
# amenities                           0
# price                               0
# security_deposit                 9361
# cleaning_fee                     7146
# guests_included                     0
# extra_people                        0
# minimum_nights                      0
# maximum_nights                      0
# number_of_reviews                   0
# review_scores_rating             4389
# review_scores_accuracy           4414
# review_scores_location           4431
# review_scores_value              4435
# cancellation_policy                 0
# reviews_per_month                3914
# dtype: int64

# %%
df['security_deposit'] = df['security_deposit'].fillna(0)

# %%
df['cleaning_fee'] = df['cleaning_fee'].fillna(0)

# %%
df.describe(exclude='number')
# Out:
#                   name                                            summary  \
# count            22493                                              21589
# unique           21873                                              21041
# top     Berlin Wohnung  with en-suite bathroom, TV, WIFI, bed linen, a...
# freq                14                                                 14
#
#                                               description  \
# count                                               22349
# unique                                              21997
# top     with en-suite bathroom, TV, WIFI, bed linen, a...
# freq                                                   12
#
#                                     neighborhood_overview  \
# count                                               11540
# unique                                              10781
# top     Welcome Traveler. The Singer Hostel and  Apart...
# freq                                                   43
#
#                                                   transit neighbourhood  \
# count                                               13036         21421
# unique                                              12308            91
# top     U-Bahn / Underground /Subway / Metro: U5 (Stra...      Neukölln
# freq                                                   26          3209
#
#        neighbourhood_group_cleansed   state zipcode property_type  \
# count                         22552   22468   21896         22552
# unique                           12      19     215            33
# top        Friedrichshain-Kreuzberg  Berlin   10245     Apartment
# freq                           5497   22417     855         20225
#
#            room_type  bed_type amenities cancellation_policy
# count          22552     22552     22552               22552
# unique             3         5     19985                   5
# top     Private room  Real Bed        {}            flexible
# freq           11534     21766        75                9102

# %%
df = df.drop(columns=['summary'], axis=1)

# %%
df.head()
# Out:
#      id                                              name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central
# 1  2695                Prenzlauer Berg close to Mauerpark
# 2  3176                   Fabulous Flat in great Location
# 3  3309                 BerlinSpot Schöneberg near KaDeWe
# 4  7071                  BrightRoom with sunny greenview!
#
#                                          description  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1  In the summertime we are spending most of our ...
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1                                                NaN
# 2  The neighbourhood is famous for its variety of...
# 3  My flat is in the middle of West-Berlin, direc...
# 4  Great neighborhood with plenty of Cafés, Baker...
#
#                                              transit    neighbourhood  \
# 0  Close to U-Bahn U8 and U2 (metro), Trams M12, ...            Mitte
# 1  Within walking distance you'll find the S-Bahn...              NaN
# 2  We are 5 min walk  away from the tram M2, whic...  Prenzlauer Berg
# 3  The public transportation is excellent: Severa...       Schöneberg
# 4  Best access to other parts of the city via pub...  Prenzlauer Berg
#
#   neighbourhood_group_cleansed   state zipcode   latitude  longitude  \
# 0                        Mitte  Berlin   10119  52.534537  13.402557
# 1                       Pankow  Berlin   10437  52.548513  13.404553
# 2                       Pankow  Berlin   10405  52.534996  13.417579
# 3       Tempelhof - Schöneberg  Berlin   10777  52.498855  13.349065
# 4                       Pankow  Berlin   10437  52.543157  13.415091
#
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0    Guesthouse  Entire home/apt             3        1.0       1.0   2.0
# 1     Apartment     Private room             2        1.0       1.0   1.0
# 2     Apartment  Entire home/apt             4        1.0       1.0   2.0
# 3     Apartment     Private room             2        1.0       1.0   1.0
# 4     Apartment     Private room             2        1.0       1.0   2.0
#
#         bed_type                                          amenities  price  \
# 0       Real Bed  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...   60.0
# 1       Real Bed  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...   17.0
# 2       Real Bed  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...   90.0
# 3  Pull-out Sofa  {Internet,Wifi,"Pets allowed","Pets live on th...   26.0
# 4       Real Bed  {Wifi,Heating,"Family/kid friendly",Essentials...   42.0
#
#    security_deposit  cleaning_fee  guests_included  extra_people  \
# 0             200.0          30.0                1          28.0
# 1               0.0           0.0                1           0.0
# 2             200.0          50.0                2          20.0
# 3             250.0          30.0                1          18.0
# 4               0.0           0.0                1          24.0
#
#    minimum_nights  maximum_nights  number_of_reviews  review_scores_rating  \
# 0               4            1125                118                  93.0
# 1               2              40                  6                 100.0
# 2              62            1125                143                  92.0
# 3               5             360                 25                  88.0
# 4               2              10                197                  96.0
#
#    review_scores_accuracy  review_scores_location  review_scores_value  \
# 0                    10.0                    10.0                  9.0
# 1                    10.0                    10.0                 10.0
# 2                     9.0                    10.0                  9.0
# 3                     9.0                     9.0                  9.0
# 4                    10.0                    10.0                  9.0
#
#            cancellation_policy  reviews_per_month
# 0  strict_14_with_grace_period               3.76
# 1                     flexible               1.42
# 2  strict_14_with_grace_period               1.25
# 3  strict_14_with_grace_period               0.39
# 4                     moderate               1.75

# %%
df = df.drop(columns=['neighbourhood'], axis=1)

# %%
df.describe(exclude='number')
# Out:
#                   name                                        description  \
# count            22493                                              22349
# unique           21873                                              21997
# top     Berlin Wohnung  with en-suite bathroom, TV, WIFI, bed linen, a...
# freq                14                                                 12
#
#                                     neighborhood_overview  \
# count                                               11540
# unique                                              10781
# top     Welcome Traveler. The Singer Hostel and  Apart...
# freq                                                   43
#
#                                                   transit  \
# count                                               13036
# unique                                              12308
# top     U-Bahn / Underground /Subway / Metro: U5 (Stra...
# freq                                                   26
#
#        neighbourhood_group_cleansed   state zipcode property_type  \
# count                         22552   22468   21896         22552
# unique                           12      19     215            33
# top        Friedrichshain-Kreuzberg  Berlin   10245     Apartment
# freq                           5497   22417     855         20225
#
#            room_type  bed_type amenities cancellation_policy
# count          22552     22552     22552               22552
# unique             3         5     19985                   5
# top     Private room  Real Bed        {}            flexible
# freq           11534     21766        75                9102

# %%
df.shape
# Out:
# (22552, 32)

# %%
df.to_csv('listings_summary_clean.csv', index=False)

# %%
df2 = pd.read_csv('listings_summary_clean.csv')

# %%
print(df2.shape)
df2.head()
# Out:
# (22552, 32)
#      id                                              name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central
# 1  2695                Prenzlauer Berg close to Mauerpark
# 2  3176                   Fabulous Flat in great Location
# 3  3309                 BerlinSpot Schöneberg near KaDeWe
# 4  7071                  BrightRoom with sunny greenview!
#
#                                          description  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1  In the summertime we are spending most of our ...
# 2  This beautiful first floor apartment  is situa...
# 3  First of all: I prefer short-notice bookings. ...
# 4  Cozy and large room in the beautiful district ...
#
#                                neighborhood_overview  \
# 0  It is located in the former East Berlin area o...
# 1                                                NaN
# 2  The neighbourhood is famous for its variety of...
# 3  My flat is in the middle of West-Berlin, direc...
# 4  Great neighborhood with plenty of Cafés, Baker...
#
#                                              transit  \
# 0  Close to U-Bahn U8 and U2 (metro), Trams M12, ...
# 1  Within walking distance you'll find the S-Bahn...
# 2  We are 5 min walk  away from the tram M2, whic...
# 3  The public transportation is excellent: Severa...
# 4  Best access to other parts of the city via pub...
#
#   neighbourhood_group_cleansed   state zipcode   latitude  longitude  \
# 0                        Mitte  Berlin   10119  52.534537  13.402557
# 1                       Pankow  Berlin   10437  52.548513  13.404553
# 2                       Pankow  Berlin   10405  52.534996  13.417579
# 3       Tempelhof - Schöneberg  Berlin   10777  52.498855  13.349065
# 4                       Pankow  Berlin   10437  52.543157  13.415091
#
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0    Guesthouse  Entire home/apt             3        1.0       1.0   2.0
# 1     Apartment     Private room             2        1.0       1.0   1.0
# 2     Apartment  Entire home/apt             4        1.0       1.0   2.0
# 3     Apartment     Private room             2        1.0       1.0   1.0
# 4     Apartment     Private room             2        1.0       1.0   2.0
#
#         bed_type                                          amenities  price  \
# 0       Real Bed  {TV,"Cable TV",Wifi,Kitchen,Gym,Heating,"Famil...   60.0
# 1       Real Bed  {Wifi,Kitchen,Elevator,Heating,Washer,Essentia...   17.0
# 2       Real Bed  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...   90.0
# 3  Pull-out Sofa  {Internet,Wifi,"Pets allowed","Pets live on th...   26.0
# 4       Real Bed  {Wifi,Heating,"Family/kid friendly",Essentials...   42.0
#
#    security_deposit  cleaning_fee  guests_included  extra_people  \
# 0             200.0          30.0                1          28.0
# 1               0.0           0.0                1           0.0
# 2             200.0          50.0                2          20.0
# 3             250.0          30.0                1          18.0
# 4               0.0           0.0                1          24.0
#
#    minimum_nights  maximum_nights  number_of_reviews  review_scores_rating  \
# 0               4            1125                118                  93.0
# 1               2              40                  6                 100.0
# 2              62            1125                143                  92.0
# 3               5             360                 25                  88.0
# 4               2              10                197                  96.0
#
#    review_scores_accuracy  review_scores_location  review_scores_value  \
# 0                    10.0                    10.0                  9.0
# 1                    10.0                    10.0                 10.0
# 2                     9.0                    10.0                  9.0
# 3                     9.0                     9.0                  9.0
# 4                    10.0                    10.0                  9.0
#
#            cancellation_policy  reviews_per_month
# 0  strict_14_with_grace_period               3.76
# 1                     flexible               1.42
# 2  strict_14_with_grace_period               1.25
# 3  strict_14_with_grace_period               0.39
# 4                     moderate               1.75
